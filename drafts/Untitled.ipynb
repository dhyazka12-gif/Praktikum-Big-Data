# %%
# !uv pip install numpy pandas
# Out:
# Using Python 3.11.16 environment at: /home/azka/.venv
# Resolved 4 packages in 463ms
# Installed 2 packages in 99ms
#  + numpy==2.4.6
#  + pandas==3.0.5

# %%
# %pip install numpy pandas
# Out:
# /home/azka/.venv/bin/python3: No module named pip
# Note: you may need to restart the kernel to use updated packages.
