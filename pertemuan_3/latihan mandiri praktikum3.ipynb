# %%
# !hdfs dfs -mkdir -p /user/mahasiswa/latihan3

# %%
# !hdfs dfs -ls /user/mahasiswa
# Out:
# Found 2 items
# drwxr-xr-x   - azka supergroup          0 2026-09-09 22:31 /user/mahasiswa/latihan3
# drwxr-xr-x   - azka supergroup          0 2026-09-09 22:00 /user/mahasiswa/praktikum

# %%
with open("biodata.txt", "w") as f:
    f.write("Nama: Azka\n")
    f.write("NIM: 123456789\n")  
    f.write("Hobi: Bermain alat musik\n")

# %%
# !hdfs dfs -put biodata.txt /user/mahasiswa/latihan3/

# %%
# !hdfs dfs -ls /user/mahasiswa/latihan3
# Out:
# Found 1 items
# -rw-r--r--   1 azka supergroup         51 2026-09-09 22:32 /user/mahasiswa/latihan3/biodata.txt

# %%
# !hdfs dfs -cat /user/mahasiswa/latihan3/biodata.txt
# Out:
# Nama: Azka
# NIM: 123456789
# Hobi: Bermain alat musik
