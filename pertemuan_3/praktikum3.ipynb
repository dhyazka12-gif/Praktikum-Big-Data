# %%
# !hdfs version
# Out:
# Hadoop 3.4.3
# Source code repository https://github.com/apache/hadoop.git -r 9d50c6884666e794e45102260a4017bb31802e1b
# Compiled by stevel on 2026-02-13T14:23Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.23.4
# From source with checksum 2331238c4c2929e66645316a32a8613
# This command was run using /home/azka/hadoop/share/hadoop/common/hadoop-common-3.4.3.jar

# %%
# !hdfs dfs -mkdir -p /user/mahasiswa/praktikum

# %%
# !hdfs dfs -ls /user/mahasiswa
# Out:
# Found 1 items
# drwxr-xr-x   - azka supergroup          0 2026-09-09 21:13 /user/mahasiswa/praktikum

# %%
with open("contoh_lokal.txt", "w") as f:
    f.write("Halo dari Praktikum Big Data!\n")
    f.write("Berkas ini awalnya tersimpan di disk lokal VM.\n")

print("Berkas lokal berhasil dibuat.")
# Out:
# Berkas lokal berhasil dibuat.

# %%
# !hdfs dfs -put contoh_lokal.txt /user/mahasiswa/praktikum/

# %%
# !hdfs dfs -ls /user/mahasiswa/praktikum/
# Out:
# Found 1 items
# -rw-r--r--   1 azka supergroup         77 2026-09-09 21:18 /user/mahasiswa/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -cat /user/mahasiswa/praktikum/contoh_lokal.txt
# Out:
# Halo dari Praktikum Big Data!
# Berkas ini awalnya tersimpan di disk lokal VM.

# %%
# !hdfs dfs -get /user/mahasiswa/praktikum/contoh_lokal.txt hasil_unduh_dari_hdfs.txt

# verifikasi dengan isi yang sama
# !cat hasil_unduh_dari_hdfs.txt
# Out:
# Halo dari Praktikum Big Data!
# Berkas ini awalnya tersimpan di disk lokal VM.

# %%
# !hdfs dfs -du -h /user/mahasiswa/praktikum
# Out:
# 77  77  /user/mahasiswa/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -count /user/mahasiswa/praktikum
# Out:
#            1            1                 77 /user/mahasiswa/praktikum

# %%
# !hdfs dfs -rm /user/mahasiswa/praktikum/contoh_lokal.txt
# Out:
# Deleted /user/mahasiswa/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -ls /user/mahasiswa/praktikum
